# %% [markdown]
# <a href="https://colab.research.google.com/github/UmutErayAltay/Ev_Fiyat_Tahmin/blob/main/selenium_ev_verisi_g%C3%BCncel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium
# !apt—get update
# !apt—get Install —y chromium—browger
# !apt install chromium-chromedriver
# Out:
# Collecting selenium
#   Downloading selenium-4.15.2-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 70.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.23.1-py3-none-any.whl (448 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.3/448.3 kB 50.0 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.3)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.15.2 trio-0.23.1 trio-websocket-0.11.1 wsproto-1.2.0
# /bin/bash: line 1: apt—get: command not found
# /bin/bash: line 1: apt—get: command not found
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor chromium-browser libfuse3-3 liblzo2-2 libudev1 snapd squashfs-tools systemd-hwe-hwdb
#   udev
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils fuse3 zenity | kdialog
# The following NEW packages will be installed:
#   apparmor chromium-browser chromium-chromedriver libfuse3-3 liblzo2-2 snapd squashfs-tools
#   systemd-hwe-hwdb udev
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 9 newly installed, 0 to remove and 9 not upgraded.
# Need to get 26.4 MB of archives.
# After this operation, 116 MB of additional disk space will be used.
# Err:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 apparmor amd64 3.0.4-2ubuntu2.2
#   404  Not Found [IP: 91.189.91.82 80]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 squashfs-tools amd64 1:4.5-3build1 [159 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.11 [78.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.11 [1,557 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfuse3-3 amd64 3.10.5-1build1 [81.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 snapd amd64 2.58+22.04.1 [23.8 MB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-browser amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [49.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 chromium-chromedriver amd64 1:85.0.4183.83-0ubuntu2.22.04.1 [2,308 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.3 [2,908 B]
# Fetched 25.8 MB in 1s (35.6 MB/s)
# E: Failed to fetch http://archive.ubuntu.com/ubuntu/pool/main/a/apparmor/apparmor_3.0.4-2ubuntu2.2_amd64.deb  404  Not Found [IP: 91.189.91.82 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?

# %%
from selenium import webdriver
import time
import pandas as pd
import numpy as np
import os

# %%
# !ls /usr/lib/chromium-browser/chromedriver
# Out:
# ls: cannot access '/usr/lib/chromium-browser/chromedriver': No such file or directory

# %%
def Veri_çekme(i,url):
  try:
    birinci_özellikler = []
    ikinci_özellikler = []
    fiyat = []
    tikla = driver.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
    i += 1
    tikla.click()
    element = driver.find_element('xpath', '//*[@id="bilgiler"]/div/div[2]/div/div[2]/span')
    driver.execute_script("arguments[0].click();", element)
    elements = driver.find_elements("css selector", '._2HQCBI')
    fiyatlar = driver.find_elements("css selector", '._2TxNQv')
    sayaç = 1
    for j in elements:
        if sayaç%2 == 1:
          birinci_özellikler.append(j.text)
          birinci_özellikler.append("\n")
        else:
          ikinci_özellikler.append(j.text)
        sayaç+=1
    toplu_dizi = birinci_özellikler + ikinci_özellikler

    for j in fiyatlar:
        fiyat.append(j.text)
    element = driver.find_elements("css selector", '._3VQ1JB')
    toplu_dizi.append("\nKonum\n")
    konumlar = ["Osmangazi", "Nilüfer", "Yıldırım", "Büyükorhan", "Gemlik", "Gürsu", "Harmancık", "İnegöl",
"İznik", "Karacabey", "Keles", "Kestel", "Mudanya", "Mustafakemalpaşa","Orhaneli","Orhangazi", "Yenişehir"]
    for j in konumlar:
        if element[0].text.find(j) != -1:
            toplu_dizi.append(j)
    fiyat_sade = fiyat[1].strip()
    fiyat_sade = fiyat_sade.replace("TL","")
    fiyat_sade = fiyat_sade.replace(".","")
    fiyat_sade = fiyat_sade.replace(",","")
    for i in range(100):
        if fiyat_sade.find("arrow_downward%"+i.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+i.__str__())!=-1:
            fiyat_sade = fiyat_sade.replace("arrow_downward%"+i.__str__(),"")
            fiyat_sade = fiyat_sade.replace("arrow_upward%"+i.__str__(),"")
    fiyat_sade = int(fiyat_sade)
    print(fiyat_sade)
    içerikler = []
    içerikler.append([fiyat_sade])
    det_str = listToString(toplu_dizi)
    ayrı = det_str.split("\n")
    print(ayrı)
    başlıklar = []
    özellikler = []
    sayaç = 1
    for i in ayrı:
      if sayaç%2==1:
        başlıklar.append(i)
      else:
        özellikler.append(i)
      sayaç+=1
    başlıklar.append("Fiyat")
    özellikler.append(fiyat_sade)
    print(başlıklar)
    print(özellikler)
    ev_df = pd.DataFrame(columns=["İlan Numarası", "İlan Güncelleme Tarihi", "Kategorisi", "Net Metrekare",
                              "Oda Sayısı", "Bulunduğu Kat", "Isıtma Tipi", "Krediye Uygunluk", "Yapı Tipi", "Takas",
                              "Yapı Durumu", "Site İçerisinde", "Banyo Sayısı", "Balkon Sayısı","İpotek Durumu", 'Kira Getirisi',
                              "Fiyat Durumu", ' İlan Oluşturma Tarihi', "Türü", "Tipi", "WC Metrekare", "Aidat",
                              "Brüt Metrekare", "Binanın Yaşı", "Binanın Kat Sayısı", "Kullanım Durumu", "Balkon Metrekare", "Banyo Metrekare",
                              "Yatırıma Uygunluk", "Tapu Durumu", "Eşya Durumu", "Balkon Durumu", "Balkon Tipi", "Görüntülü Gezilebilir Mi?",
                              "WC Sayısı", "Konum", "Fiyat"])
    # Ev verilerini sırayla işle
    for i in range(len(başlıklar)):
        # Gelen ev başlığı
        ev_başlığı = başlıklar[i]

        # Gelen ev özelliği
        ev_özelliği = özellikler[i]

        # Başlık uyumunu kontrol et
        if ev_başlığı in ev_df.columns:
            # Başlık uyumu varsa, ilgili başlık altındaki özelliği ekle
            ev_df.at[0, ev_başlığı] = ev_özelliği
        else:
          pass
            ## Başlık uyumu yoksa, yeni sütun ekleyerek başlık ve özelliği ekle
            #ev_df[ev_başlığı] = ""
            #ev_df.at[0, ev_başlığı] = ev_özelliği

    # DataFrame'i göster
    print(ev_df)

    driver.execute_script("window.history.go(-1)")
    if not os.path.isfile("ev_verileri.csv"):
      # Dosya zaten varsa yeniden oluşturmaya gerek yok
      ev_df.to_csv("ev_verileri.csv", encoding="utf-8", index=False)
    else:
        # Dosya henüz oluşturulmamışsa, mode="a" kullanarak append et
        ev_df.to_csv("ev_verileri.csv", encoding="utf-8", index=False, mode="a", header=False)
  except:
    url_in = driver.current_url
    print(i,"Hatalı")
    driver.execute_script("window.history.go(-1)")
    if url_in != url:
        driver.get(url)

# %%
def listToString(s):
    # initialize an empty string
    str1 = " "
    # return string
    return (str1.join(s))

# %%
options = webdriver.ChromeOptions()
options.add_argument( '--no-sandbox' )
options.add_argument( '--headless' )
options.add_argument( '--disable-gpu' )
options.add_argument('--disable-dve-shm-uage')
driver = webdriver.Chrome(options=options)

# %%
k = 1
url = "https://www.emlakjet.com/satilik-konut/bursa/"
while (k<=50):
    if(k!=1):
        driver.get("https://www.emlakjet.com/satilik-konut/bursa/"+str(k))
        url="https://www.emlakjet.com/satilik-konut/bursa/"+str(k)
    k+=1
    i=1
    while (i<=38):
      Veri_çekme(i,url)
      i+=1

driver.quit()
# Out:
# 1 Hatalı
# 875000
# ['İlan Numarası', '14294785', 'İlan Güncelleme Tarihi', '23 Kasım 2023', 'Kategorisi', 'Satılık', 'Net Metrekare', '60 M2', 'Oda Sayısı', '1+1', 'Bulunduğu Kat', '1.Kat', 'Isıtma Tipi', 'Kombi Doğalgaz', 'Krediye Uygunluk', 'Bilinmiyor', 'Yapı Durumu', 'İkinci El', 'Site İçerisinde', 'Hayır', 'Banyo Sayısı', '1', 'Balkon Sayısı', '1', 'Fiyat Durumu', 'Genel Fiyat ', ' İlan Oluşturma Tarihi', '23 Kasım 2023', 'Türü', 'Konut', 'Tipi', 'Daire', 'Brüt Metrekare', '70 M2', 'Binanın Yaşı', '21 Ve Üzeri', 'Binanın Kat Sayısı', '4', 'Kullanım Durumu', 'Boş', 'Yatırıma Uygunluk', 'Yatırıma Uygun', 'Tapu Durumu', 'Müstakil Tapulu', 'Eşya Durumu', 'Eşyalı', 'Balkon Durumu', 'Var', 'WC Sayısı', '1 ', 'Konum', ' Osmangazi']
# ['İlan Numarası', 'İlan Güncelleme Tarihi', 'Kategorisi', 'Net Metrekare', 'Oda Sayısı', 'Bulunduğu Kat', 'Isıtma Tipi', 'Krediye Uygunluk', 'Yapı Durumu', 'Site İçerisinde', 'Banyo Sayısı', 'Balkon Sayısı', 'Fiyat Durumu', ' İlan Oluşturma Tarihi', 'Türü', 'Tipi', 'Brüt Metrekare', 'Binanın Yaşı', 'Binanın Kat Sayısı', 'Kullanım Durumu', 'Yatırıma Uygunluk', 'Tapu Durumu', 'Eşya Durumu', 'Balkon Durumu', 'WC Sayısı', 'Konum', 'Fiyat']
# ['14294785', '23 Kasım 2023', 'Satılık', '60 M2', '1+1', '1.Kat', 'Kombi Doğalgaz', 'Bilinmiyor', 'İkinci El', 'Hayır', '1', '1', 'Genel Fiyat ', '23 Kasım 2023', 'Konut', 'Daire', '70 M2', '21 Ve Üzeri', '4', 'Boş', 'Yatırıma Uygun', 'Müstakil Tapulu', 'Eşyalı', 'Var', '1 ', ' Osmangazi', 875000]
#   İlan Numarası İlan Güncelleme Tarihi Kategorisi Net Metrekare Oda Sayısı  \
# 0      14294785          23 Kasım 2023    Satılık         60 M2        1+1
#
#   Bulunduğu Kat     Isıtma Tipi Krediye Uygunluk Yapı Tipi Takas  ...  \
# 0         1.Kat  Kombi Doğalgaz       Bilinmiyor       NaN   NaN  ...
#
#   Banyo Metrekare Yatırıma Uygunluk      Tapu Durumu Eşya Durumu  \
# 0             NaN    Yatırıma Uygun  Müstakil Tapulu      Eşyalı
#
#   Balkon Durumu Balkon Tipi Görüntülü Gezilebilir Mi? WC Sayısı       Konum  \
# 0           Var         NaN                       NaN        1    Osmangazi
#
#     Fiyat
# 0  875000
#
# [1 rows x 37 columns]
# 4 Hatalı
# 4 Hatalı
# 3500000
# ['İlan Numarası', '14294650', 'İlan Güncelleme Tarihi', '23 Kasım 2023', 'Kategorisi', 'Satılık', 'Net Metrekare', '80 M2', 'Oda Sayısı', '2+1', 'Bulunduğu Kat', '6.Kat', 'Isıtma Tipi', 'Merkezi Doğalgaz', 'Krediye Uygunluk', 'Krediye Uygun', 'Yapı Durumu', 'Sıfır', 'Tapu Durumu', 'Kat Mülkiyeti', 'İpotek Durumu', 'Yok', 'Takas', 'Yok', 'Balkon Durumu', 'Var ', ' İlan Oluşturma Tarihi', '23 Kasım 2023', 'Türü', 'Konut', 'Tipi', 'Daire', 'Brüt Metrekare', '85 M2', 'Binanın Yaşı', '0 (Yeni)', 'Binanın Kat Sayısı', '7', 'Kullanım Durumu', 'Boş', 'Yatırıma Uygunluk', 'Yatırıma Uygun', 'Yapı Tipi', 'Betonarme', 'Site İçerisinde', 'Hayır', 'Eşya Durumu', 'Boş', 'Banyo Sayısı', '2', 'Fiyat Durumu', 'Genel Fiyat ', 'Konum', ' Yıldırım']
# ['İlan Numarası', 'İlan Güncelleme Tarihi', 'Kategorisi', 'Net Metrekare', 'Oda Sayısı', 'Bulunduğu Kat', 'Isıtma Tipi', 'Krediye Uygunluk', 'Yapı Durumu', 'Tapu Durumu', 'İpotek Durumu', 'Takas', 'Balkon Durumu', ' İlan Oluşturma Tarihi', 'Türü', 'Tipi', 'Brüt Metrekare', 'Binanın Yaşı', 'Binanın Kat Sayısı', 'Kullanım Durumu', 'Yatırıma Uygunluk', 'Yapı Tipi', 'Site İçerisinde', 'Eşya Durumu', 'Banyo Sayısı', 'Fiyat Durumu', 'Konum', 'Fiyat']
# ['14294650', '23 Kasım 2023', 'Satılık', '80 M2', '2+1', '6.Kat', 'Merkezi Doğalgaz', 'Krediye Uygun', 'Sıfır', 'Kat Mülkiyeti', 'Yok', 'Yok', 'Var ', '23 Kasım 2023', 'Konut', 'Daire', '85 M2', '0 (Yeni)', '7', 'Boş', 'Yatırıma Uygun', 'Betonarme', 'Hayır', 'Boş', '2', 'Genel Fiyat ', ' Yıldırım', 3500000]
#   İlan Numarası İlan Güncelleme Tarihi Kategorisi Net Metrekare Oda Sayısı  \
# 0      14294650          23 Kasım 2023    Satılık         80 M2        2+1
#
#   Bulunduğu Kat       Isıtma Tipi Krediye Uygunluk  Yapı Tipi Takas  ...  \
# 0         6.Kat  Merkezi Doğalgaz    Krediye Uygun  Betonarme   Yok  ...
#
#   Banyo Metrekare Yatırıma Uygunluk    Tapu Durumu Eşya Durumu Balkon Durumu  \
# 0             NaN    Yatırıma Uygun  Kat Mülkiyeti         Boş          Var
#
#   Balkon Tipi Görüntülü Gezilebilir Mi? WC Sayısı      Konum    Fiyat
# 0         NaN                       NaN       NaN   Yıldırım  3500000
#
# [1 rows x 37 columns]
# 5250000
# ['İlan Numarası', '14284983', 'İlan Güncelleme Tarihi', '24 Kasım 2023', 'Kategorisi', 'Satılık', 'Net Metrekare', '320 M2', 'Oda Sayısı', '6+1', 'Bulunduğu Kat', '9.Kat', 'Isıtma Tipi', 'Kombi Doğalgaz', 'Krediye Uygunluk', 'Krediye Uygun', 'Aidat', '200 TL', 'Banyo Sayısı', '2 ', ' İlan Oluşturma Tarihi', '21 Kasım 2023', 'Türü', 'Konut', 'Tipi', 'Daire', 'Brüt Metrekare', '325 M2', 'Binanın Yaşı', '5-10', 'Binanın Kat Sayısı', '10', 'Kullanım Durumu', 'Boş', 'Site İçerisinde', 'Evet', 'Kira Getirisi', '25000 TL', 'Fiyat Durumu', 'Genel Fiyat ', 'Konum', ' Yıldırım']
# ['İlan Numarası', 'İlan Güncelleme Tarihi', 'Kategorisi', 'Net Metrekare', 'Oda Sayısı', 'Bulunduğu Kat', 'Isıtma Tipi', 'Krediye Uygunluk', 'Aidat', 'Banyo Sayısı', ' İlan Oluşturma Tarihi', 'Türü', 'Tipi', 'Brüt Metrekare', 'Binanın Yaşı', 'Binanın Kat Sayısı', 'Kullanım Durumu', 'Site İçerisinde', 'Kira Getirisi', 'Fiyat Durumu', 'Konum', 'Fiyat']
# ['14284983', '24 Kasım 2023', 'Satılık', '320 M2', '6+1', '9.Kat', 'Kombi Doğalgaz', 'Krediye Uygun', '200 TL', '2 ', '21 Kasım 2023', 'Konut', 'Daire', '325 M2', '5-10', '10', 'Boş', 'Evet', '25000 TL', 'Genel Fiyat ', ' Yıldırım', 5250000]
#   İlan Numarası İlan Güncelleme Tarihi Kategorisi Net Metrekare Oda Sayısı  \
# 0      14284983          24 Kasım 2023    Satılık        320 M2        6+1
#
#   Bulunduğu Kat     Isıtma Tipi Krediye Uygunluk Yapı Tipi Takas  ...  \
# 0         9.Kat  Kombi Doğalgaz    Krediye Uygun       NaN   NaN  ...
#
#   Banyo Metrekare Yatırıma Uygunluk Tapu Durumu Eşya Durumu Balkon Durumu  \
# 0             NaN               NaN         NaN         NaN           NaN
#
#   Balkon Tipi Görüntülü Gezilebilir Mi? WC Sayısı      Konum    Fiyat
# 0         NaN                       NaN       NaN   Yıldırım  5250000
#
# [1 rows x 37 columns]
# 3000000
# ['İlan Numarası', '14283696', 'İlan Güncelleme Tarihi', '21 Kasım 2023', 'Kategorisi', 'Satılık', 'Net Metrekare', '110 M2', 'Oda Sayısı', '3+1', 'Bulunduğu Kat', '1.Kat', 'Isıtma Tipi', 'Kombi Doğalgaz', 'Krediye Uygunluk', 'Krediye Uygun', 'Banyo Sayısı', '1', 'Balkon Sayısı', '2', 'Fiyat Durumu', 'Genel Fiyat ', ' İlan Oluşturma Tarihi', '21 Kasım 2023', 'Türü', 'Konut', 'Tipi', 'Daire', 'Brüt Metrekare', '130 M2', 'Binanın Yaşı', '11-15', 'Binanın Kat Sayısı', '5', 'Kullanım Durumu', 'Boş', 'Site İçerisinde', 'Evet', 'Balkon Durumu', 'Var', 'Balkon Tipi', 'Açık Balkon ', 'Konum', ' Mudanya']
# ['İlan Numarası', 'İlan Güncelleme Tarihi', 'Kategorisi', 'Net Metrekare', 'Oda Sayısı', 'Bulunduğu Kat', 'Isıtma Tipi', 'Krediye Uygunluk', 'Banyo Sayısı', 'Balkon Sayısı', 'Fiyat Durumu', ' İlan Oluşturma Tarihi', 'Türü', 'Tipi', 'Brüt Metrekare', 'Binanın Yaşı', 'Binanın Kat Sayısı', 'Kullanım Durumu', 'Site İçerisinde', 'Balkon Durumu', 'Balkon Tipi', 'Konum', 'Fiyat']
# ['14283696', '21 Kasım 2023', 'Satılık', '110 M2', '3+1', '1.Kat', 'Kombi Doğalgaz', 'Krediye Uygun', '1', '2', 'Genel Fiyat ', '21 Kasım 2023', 'Konut', 'Daire', '130 M2', '11-15', '5', 'Boş', 'Evet', 'Var', 'Açık Balkon ', ' Mudanya', 3000000]
#   İlan Numarası İlan Güncelleme Tarihi Kategorisi Net Metrekare Oda Sayısı  \
# 0      14283696          21 Kasım 2023    Satılık        110 M2        3+1
#
#   Bulunduğu Kat     Isıtma Tipi Krediye Uygunluk Yapı Tipi Takas  ...  \
# 0         1.Kat  Kombi Doğalgaz    Krediye Uygun       NaN   NaN  ...
#
#   Banyo Metrekare Yatırıma Uygunluk Tapu Durumu Eşya Durumu Balkon Durumu  \
# 0             NaN               NaN         NaN         NaN           Var
#
#     Balkon Tipi Görüntülü Gezilebilir Mi? WC Sayısı     Konum    Fiyat
# 0  Açık Balkon                        NaN       NaN   Mudanya  3000000
#
# [1 rows x 37 columns]
# 9 Hatalı
# 9 Hatalı
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-199-3fa9a8c086d4> in Veri_çekme(i, url)
#       5     fiyat = []
# ----> 6     tikla = driver.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
#       7     i += 1
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     740
# --> 741         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     742
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     346         if response:
# --> 347             self.error_handler.check_response(response)
#     348             response["value"] = self._unwrap_value(response.get("value", None))
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="listing-search-wrapper"]/div[9]"}
#   (Session info: headless chrome=119.0.6045.105); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x5c6421a9d5e3 <unknown>
# #1 0x5c64217600b7 <unknown>
# #2 0x5c64217adf53 <unknown>
# #3 0x5c64217ae051 <unknown>
# #4 0x5c64217f39c4 <unknown>
# #5 0x5c64217d4f1d <unknown>
# #6 0x5c64217f0b3d <unknown>
# #7 0x5c64217d4cc3 <unknown>
# #8 0x5c64217a00e4 <unknown>
# #9 0x5c64217a10ae <unknown>
# #10 0x5c6421a63ce1 <unknown>
# #11 0x5c6421a67b7e <unknown>
# #12 0x5c6421a514b5 <unknown>
# #13 0x5c6421a687d6 <unknown>
# #14 0x5c6421a34dbf <unknown>
# #15 0x5c6421a8b748 <unknown>
# #16 0x5c6421a8b917 <unknown>
# #17 0x5c6421a9c773 <unknown>
# #18 0x7b67621e8ac3 <unknown>
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-202-4ee87671b01a> in <cell line: 3>()
#       8     i=1
#       9     while (i<=38):
# ---> 10       Veri_çekme(i,url)
#      11       i+=1
#      12
#
# <ipython-input-199-3fa9a8c086d4> in Veri_çekme(i, url)
#      98     driver.execute_script("window.history.go(-1)")
#      99     if url_in != url:
# --> 100         driver.get(url)
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     354     def get(self, url: str) -> None:
#     355         """Loads a web page in the current browser session."""
# --> 356         self.execute(Command.GET, {"url": url})
#     357
#     358     @property
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     343                 params["sessionId"] = self.session_id
#     344
# --> 345         response = self.command_executor.execute(driver_command, params)
#     346         if response:
#     347             self.error_handler.check_response(response)
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     298         data = utils.dump_json(params)
#     299         url = f"{self._url}{path}"
# --> 300         return self._request(command_info[0], url, body=data)
#     301
#     302     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     319
#     320         if self.keep_alive:
# --> 321             response = self._conn.request(method, url, body=body, headers=headers)
#     322             statuscode = response.status
#     323         else:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/_request_methods.py in request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     116             )
#     117         else:
# --> 118             return self.request_encode_body(
#     119                 method, url, fields=fields, headers=headers, **urlopen_kw
#     120             )
#
# /usr/local/lib/python3.10/dist-packages/urllib3/_request_methods.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     215         extra_kw.update(urlopen_kw)
#     216
# --> 217         return self.urlopen(method, url, **extra_kw)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     441             response = conn.urlopen(method, url, **kw)
#     442         else:
# --> 443             response = conn.urlopen(method, u.request_uri, **kw)
#     444
#     445         redirect_location = redirect and response.get_redirect_location()
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
    df = pd.DataFrame(ayrı)
    df_yeni = df.iloc[0:]
    print(df_yeni)

    df_yeni = df_yeni.reset_index()
    df_yeni.drop("index", axis=1, inplace=True)
    df_liste = df_yeni.values.tolist()
    a = 1
    print(len(df_yeni))
    while a <= len(df_yeni):
      içerikler.append(df_liste[a])
      a= a+2
      if a>=len(df_yeni):
        break
    df_içerikler = pd.DataFrame(içerikler).T
    df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")

# %%
# CSV dosyasını oku
dosya_yolu = "ev_verileri.csv"
ev_verileri = pd.read_csv(dosya_yolu, encoding="utf-8", error_bad_lines=False, warn_bad_lines=True)

# DataFrame'i göster
print(ev_verileri)
# Out:
#    İlan Numarası İlan Güncelleme Tarihi Kategorisi Net Metrekare Oda Sayısı  \
# 0       14294785          23 Kasım 2023    Satılık         60 M2        1+1
# 1       14294650          23 Kasım 2023    Satılık         80 M2        2+1
# 2       14283696          21 Kasım 2023    Satılık        110 M2        3+1
#
#   Bulunduğu Kat       Isıtma Tipi Krediye Uygunluk  Yapı Tipi Takas  ...  \
# 0         1.Kat    Kombi Doğalgaz       Bilinmiyor        NaN   NaN  ...
# 1         6.Kat  Merkezi Doğalgaz    Krediye Uygun  Betonarme   Yok  ...
# 2         1.Kat    Kombi Doğalgaz    Krediye Uygun        NaN   NaN  ...
#
#        Tapu Durumu Eşya Durumu  Balkon Durumu   Balkon Tipi  \
# 0  Müstakil Tapulu      Eşyalı            Var           NaN
# 1    Kat Mülkiyeti         Boş           Var            NaN
# 2              NaN         NaN            Var  Açık Balkon
#
#   Görüntülü Gezilebilir Mi?  WC Sayısı       Konum   Fiyat Durumu  \
# 0                       NaN        1.0   Osmangazi   Genel Fiyat
# 1                       NaN        NaN    Yıldırım  23 Kasım 2023
# 2                       NaN        NaN     Mudanya   Genel Fiyat
#
#    İlan Oluşturma Tarihi  Brüt Metrekare
# 0          23 Kasım 2023           70 M2
# 1                  85 M2    Genel Fiyat
# 2          21 Kasım 2023          130 M2
#
# [3 rows x 37 columns]
# <ipython-input-189-993789952bb0>:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ev_verileri = pd.read_csv(dosya_yolu, encoding="utf-8", error_bad_lines=False, warn_bad_lines=True)
# <ipython-input-189-993789952bb0>:3: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ev_verileri = pd.read_csv(dosya_yolu, encoding="utf-8", error_bad_lines=False, warn_bad_lines=True)
# Skipping line 4: expected 37 fields, saw 39

# %%
ev_verileri
# Out:
#    İlan Numarası İlan Güncelleme Tarihi Kategorisi Net Metrekare Oda Sayısı  \
# 0       14294785          23 Kasım 2023    Satılık         60 M2        1+1
# 1       14294650          23 Kasım 2023    Satılık         80 M2        2+1
# 2       14283696          21 Kasım 2023    Satılık        110 M2        3+1
#
#   Bulunduğu Kat       Isıtma Tipi Krediye Uygunluk  Yapı Tipi Takas  ...  \
# 0         1.Kat    Kombi Doğalgaz       Bilinmiyor        NaN   NaN  ...
# 1         6.Kat  Merkezi Doğalgaz    Krediye Uygun  Betonarme   Yok  ...
# 2         1.Kat    Kombi Doğalgaz    Krediye Uygun        NaN   NaN  ...
#
#        Tapu Durumu Eşya Durumu  Balkon Durumu   Balkon Tipi  \
# 0  Müstakil Tapulu      Eşyalı            Var           NaN
# 1    Kat Mülkiyeti         Boş           Var            NaN
# 2              NaN         NaN            Var  Açık Balkon
#
#   Görüntülü Gezilebilir Mi?  WC Sayısı       Konum   Fiyat Durumu  \
# 0                       NaN        1.0   Osmangazi   Genel Fiyat
# 1                       NaN        NaN    Yıldırım  23 Kasım 2023
# 2                       NaN        NaN     Mudanya   Genel Fiyat
#
#    İlan Oluşturma Tarihi  Brüt Metrekare
# 0          23 Kasım 2023           70 M2
# 1                  85 M2    Genel Fiyat
# 2          21 Kasım 2023          130 M2
#
# [3 rows x 37 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ev_verileri['İlan Numarası'].plot(kind='hist', bins=20, title='İlan Numarası')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ev_verileri['Banyo Sayısı'].plot(kind='hist', bins=20, title='Banyo Sayısı')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ev_verileri['Balkon Sayısı'].plot(kind='hist', bins=20, title='Balkon Sayısı')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ev_verileri['Binanın Kat Sayısı'].plot(kind='hist', bins=20, title='Binanın Kat Sayısı')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ev_verileri.groupby('İlan Güncelleme Tarihi').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ev_verileri.groupby('Net Metrekare').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ev_verileri.groupby('Oda Sayısı').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ev_verileri.groupby('Bulunduğu Kat').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ev_verileri.plot(kind='scatter', x='İlan Numarası', y='Banyo Sayısı', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ev_verileri.plot(kind='scatter', x='Banyo Sayısı', y='Balkon Sayısı', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ev_verileri.plot(kind='scatter', x='Balkon Sayısı', y='Binanın Kat Sayısı', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ev_verileri.plot(kind='scatter', x='Binanın Kat Sayısı', y='WC Sayısı', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ev_verileri['İlan Numarası'].plot(kind='line', figsize=(8, 4), title='İlan Numarası')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# ev_verileri['Banyo Sayısı'].plot(kind='line', figsize=(8, 4), title='Banyo Sayısı')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# ev_verileri['Balkon Sayısı'].plot(kind='line', figsize=(8, 4), title='Balkon Sayısı')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# ev_verileri['Binanın Kat Sayısı'].plot(kind='line', figsize=(8, 4), title='Binanın Kat Sayısı')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Net Metrekare'].value_counts()
#     for x_label, grp in ev_verileri.groupby('İlan Güncelleme Tarihi')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('İlan Güncelleme Tarihi')
# _ = plt.ylabel('Net Metrekare')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Oda Sayısı'].value_counts()
#     for x_label, grp in ev_verileri.groupby('Net Metrekare')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Net Metrekare')
# _ = plt.ylabel('Oda Sayısı')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Bulunduğu Kat'].value_counts()
#     for x_label, grp in ev_verileri.groupby('Oda Sayısı')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Oda Sayısı')
# _ = plt.ylabel('Bulunduğu Kat')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Isıtma Tipi'].value_counts()
#     for x_label, grp in ev_verileri.groupby('Bulunduğu Kat')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Bulunduğu Kat')
# _ = plt.ylabel('Isıtma Tipi')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(ev_verileri['İlan Güncelleme Tarihi'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(ev_verileri, x='İlan Numarası', y='İlan Güncelleme Tarihi', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(ev_verileri['Net Metrekare'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(ev_verileri, x='İlan Numarası', y='Net Metrekare', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(ev_verileri['Oda Sayısı'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(ev_verileri, x='İlan Numarası', y='Oda Sayısı', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(ev_verileri['Bulunduğu Kat'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(ev_verileri, x='İlan Numarası', y='Bulunduğu Kat', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# Warning: Total number of columns (37) exceeds max_columns (20) limiting to first (20) columns.

# %%
ev_df
# Out:
# Empty DataFrame
# Columns: [İlan Numarası, İlan Güncelleme Tarihi, Kategorisi, Net Metrekare, Oda Sayısı, Bulunduğu Kat, Isıtma Tipi, Krediye Uygunluk, Yapı Durumu, Site İçerisinde, Banyo Sayısı, Balkon Sayısı, Fiyat Durumu, Genel Fiyat, İlan Oluşturma Tarihi, Türü, Tipi, Brüt Metrekare, Binanın Yaşı, Binanın Kat Sayısı, Kullanım Durumu, Yatırıma Uygunluk, Tapu Durumu, Eşya Durumu, Balkon Durumu, WC Sayısı, Konum]
# Index: []
#
# [0 rows x 27 columns]
