# %%
from selenium import webdriver
import time
import pandas as pd
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from sklearn import model_selection
from playsound import playsound

# %%
browser = webdriver.Chrome()
def listToString(s):  
    # initialize an empty string 
    str1 = " " 
    # return string   
    return (str1.join(s)) 
browser.get("https://www.emlakjet.com/satilik-konut/bursa/")
k = 49
while (k<=50):
    if(k!=1):
        browser.get("https://www.emlakjet.com/satilik-konut/bursa/"+str(k))
        
    browser.minimize_window()
    k+=1
    time.sleep(1)
    i=9
    while (i<=10):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]
 

            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 12
    while (i<=13):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 1
    while (i<=2):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    
    i=4
    while (i<=7):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 650);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        time.sleep(3)
        tikla.click()
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 15
    while (i<=17):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 18
    while (i<=24):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 26
    while (i<=31):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 33
    while (i<=34):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)

            df_yeni = df.iloc[6:26]

            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
browser.quit()
playsound("GoogleChromeKapaniyor.mp3")
# Out:
# 1880000
# 1285000
# 2850000
# 399000
# 2600000
# 2450000
# 5250000
# 850000
# 540000
# 870000
# 1850000
# 2375000
# 785000
# 739000
# 1325000
# 1550000
# 1250000
# 2400000
# 2900000
# 1600000
# 4600000
# 3200000
# 13900000
# 1020000
# 2050000
# 3825000
# 6550000
# 2900000
# 1100000
# 799000
# 875000
# 1699000
# 3729000
# 3729000
# 1450000
# 2000000
# 2499000
# 879000
# 750000
# 775000
# 1900000
# 1200000
# 775000
# 1650000
# 1540000
# 1200000
# 1270000
# 1800000
# 1040000
# 2050000
# 2920000
# 1600000
# 1150000
# 1120000
# 2900000
# 2470000
# 1765000
# 1250000
# 1900000
# 1200000
# 4000000
# 2600000
# 2615000
# 2615000
# 1675000
# 2070000
# 450000
# 1650000
# 570000
# 1590000
# 1250000
# 3450000
# 550000
# 2080000
# 850000
# 3650000
# 999000
# 1460000
# 1650000
# 4600000
# 2600000
# 990000
# 2180000
# 1245000
# 1790000
# 720000
# 650000
# 870000
# 1750000
# 1000000
# 1050000
# 2900000
# 1000000
# 4850000
# 9200000
# 4990000
# 2250000
# 4300000
# 1550000
# 1350000
# 840000
# 1985000
# 1725000
# 2155000
# 650000
# 1475000
# 2895000
# 3400000
# 5625000
# 1650000
# 1360000
# 1350000
# 1800000
# 2950000
# 5250000
# 1260000
# 6950000
# 1395000
# 1270000
# 350000
# 885000
# 425000
# 1160000
# 1229000
# 1250000
# 1150000
# 879000
# 4500000
# 3100000
# 2400000
# 520000
# 1100000
# 1565000
# 1890000
# 1690000
# 2900000
# 2200000
# 2550000
# 1380000
# 950000
# 4000000
# 2100000
# 1550000
# 2995000
# 550000
# 2490000
# 23000000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [13], in <cell line: 9>()
#     181 for j in fiyatlar:
#     182     fiyat.append(j.text)
# --> 183 fiyat_sade = fiyat[1].strip()
#     184 fiyat_sade = fiyat_sade.replace("TL","")
#     185 fiyat_sade = fiyat_sade.replace(".","")
#
# IndexError: list index out of range

# %%
df_zingat = pd.read_csv("zingat3.csv")

# %%
df_zingat
# Out:
#             0       1            2  3                     4               5  \
# 0     2150000  110 M2         5-10  5       Kiracı Oturuyor    04 Ocak 2023
# 1           0       1            2  3                     4               5
# 2     4610000  300 M2         5-10  3  Mülk Sahibi Oturuyor    04 Ocak 2023
# 3           0       1            2  3                     4               5
# 4     1200000  120 M2     0 (Yeni)  4                   Boş    04 Ocak 2023
# ...       ...     ...          ... ..                   ...             ...
# 2608  2995000  145 M2         5-10  2  Mülk Sahibi Oturuyor  14 Aralık 2022
# 2609        0       1            2  3                     4               5
# 2610   550000   90 M2  21 Ve Üzeri  5       Kiracı Oturuyor  14 Aralık 2022
# 2611        0       1            2  3                     4               5
# 2612  2490000  165 M2         5-10  4  Mülk Sahibi Oturuyor  14 Aralık 2022
#
#           6       7    8             9              10
# 0     Konut  100 M2  2+1         3.Kat  Kombi Doğalgaz
# 1         6       7    8             9              10
# 2     Konut  250 M2  5+1  Bahçe Dublex  Kombi Doğalgaz
# 3         6       7    8             9              10
# 4     Konut  110 M2  3+1  Yüksek Giriş  Kombi Doğalgaz
# ...     ...     ...  ...           ...             ...
# 2608  Konut  130 M2  3+1         1.Kat  Kombi Doğalgaz
# 2609      6       7    8             9              10
# 2610  Konut   75 M2  2+1         5.Kat  Kombi Doğalgaz
# 2611      6       7    8             9              10
# 2612  Konut  135 M2  3+1  Çatı Dubleks  Kombi Doğalgaz
#
# [2613 rows x 11 columns]

# %%
i = 1
while i <= 2613:
    df_zingat.drop(i,inplace = True)
    i=i+2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 i = 1
#       2 while i <= 2613:
# ----> 3     df_zingat.drop(i,inplace = True)
#       4     i=i+2
#
# File ~\anaconda4\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda4\lib\site-packages\pandas\core\frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4774 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4775 def drop(
#    4776     self,
#    (...)
#    4783     errors: str = "raise",
#    4784 ):
#    4785     """
#    4786     Drop specified labels from rows or columns.
#    4787
#    (...)
#    4904             weight  1.0     0.8
#    4905     """
# -> 4906     return super().drop(
#    4907         labels=labels,
#    4908         axis=axis,
#    4909         index=index,
#    4910         columns=columns,
#    4911         level=level,
#    4912         inplace=inplace,
#    4913         errors=errors,
#    4914     )
#
# File ~\anaconda4\lib\site-packages\pandas\core\generic.py:4150, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148 for axis, labels in axes.items():
#    4149     if labels is not None:
# -> 4150         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4152 if inplace:
#    4153     self._update_inplace(obj)
#
# File ~\anaconda4\lib\site-packages\pandas\core\generic.py:4185, in NDFrame._drop_axis(self, labels, axis, level, errors)
#    4183         new_axis = axis.drop(labels, level=level, errors=errors)
#    4184     else:
# -> 4185         new_axis = axis.drop(labels, errors=errors)
#    4186     result = self.reindex(**{axis_name: new_axis})
#    4188 # Case for non-unique axis
#    4189 else:
#
# File ~\anaconda4\lib\site-packages\pandas\core\indexes\base.py:6017, in Index.drop(self, labels, errors)
#    6015 if mask.any():
#    6016     if errors != "ignore":
# -> 6017         raise KeyError(f"{labels[mask]} not found in axis")
#    6018     indexer = indexer[~mask]
#    6019 return self.delete(indexer)
#
# KeyError: '[2613] not found in axis'

# %%
df_zingat = df_zingat.reset_index()
df_zingat.drop("index", axis = 1, inplace = True)
