# %%
from selenium import webdriver
import time
import pandas as pd
import numpy as np

# %%
browser = webdriver.Chrome()
def listToString(s):  
    # initialize an empty string 
    str1 = " " 
    # return string   
    return (str1.join(s)) 
browser.get("https://www.emlakjet.com/satilik-konut/bursa/")
k = 49
while (k<=50):
    if(k!=1):
        browser.get("https://www.emlakjet.com/satilik-konut/bursa/"+str(k))
        
    browser.minimize_window()
    k+=1
    time.sleep(1)
    i=9
    while (i<=10):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]
 

            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 12
    while (i<=13):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 1
    while (i<=2):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    
    i=4
    while (i<=7):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 650);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        time.sleep(3)
        tikla.click()
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 15
    while (i<=17):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 18
    while (i<=24):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 26
    while (i<=31):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 33
    while (i<=34):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)

            df_yeni = df.iloc[6:26]

            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
browser.quit()
# Out:
# 1880000
# 1285000
# 2850000
# 399000
# 2600000
# 2450000
# 5250000
# 850000
# 540000
# 870000
# 1850000
# 2375000
# 785000
# 739000
# 1325000
# 1550000
# 1250000
# 2400000
# 2900000
# 1600000
# 4600000
# 3200000
# 13900000
# 1020000
# 2050000
# 3825000
# 6550000
# 2900000
# 1100000
# 799000
# 875000
# 1699000
# 3729000
# 3729000
# 1450000
# 2000000
# 2499000
# 879000
# 750000
# 775000
# 1900000
# 1200000
# 775000
# 1650000
# 1540000
# 1200000
# 1270000
# 1800000
# 1040000
# 2050000
# 2920000
# 1600000
# 1150000
# 1120000
# 2900000
# 2470000
# 1765000
# 1250000
# 1900000
# 1200000
# 4000000
# 2600000
# 2615000
# 2615000
# 1675000
# 2070000
# 450000
# 1650000
# 570000
# 1590000
# 1250000
# 3450000
# 550000
# 2080000
# 850000
# 3650000
# 999000
# 1460000
# 1650000
# 4600000
# 2600000
# 990000
# 2180000
# 1245000
# 1790000
# 720000
# 650000
# 870000
# 1750000
# 1000000
# 1050000
# 2900000
# 1000000
# 4850000
# 9200000
# 4990000
# 2250000
# 4300000
# 1550000
# 1350000
# 840000
# 1985000
# ...

# %%
df_zingat = pd.read_csv("zingat3.csv")
df_zingat
# Out:
#             0       1            2  3                     4               5  \
# 0     2150000  110 M2         5-10  5       Kiracı Oturuyor    04 Ocak 2023
# 1           0       1            2  3                     4               5
# 2     4610000  300 M2         5-10  3  Mülk Sahibi Oturuyor    04 Ocak 2023
# 3           0       1            2  3                     4               5
# 4     1200000  120 M2     0 (Yeni)  4                   Boş    04 Ocak 2023
# ...       ...     ...          ... ..                   ...             ...
# 2608  2995000  145 M2         5-10  2  Mülk Sahibi Oturuyor  14 Aralık 2022
# 2609        0       1            2  3                     4               5
# 2610   550000   90 M2  21 Ve Üzeri  5       Kiracı Oturuyor  14 Aralık 2022
# 2611        0       1            2  3                     4               5
# 2612  2490000  165 M2         5-10  4  Mülk Sahibi Oturuyor  14 Aralık 2022
#
#           6       7    8             9              10
# ...

# %%
i = 1
while i <= 2612:
    df_zingat.drop(i,inplace = True)
    i=i+2

# %%
df_zingat = df_zingat.reset_index()
df_zingat.drop("index", axis = 1, inplace = True)
df_zingat.to_csv("zingat4.csv")

# %%
df_zingat
# Out:
#             0       1            2  3                     4                5  \
# 0     2150000  110 M2         5-10  5       Kiracı Oturuyor     04 Ocak 2023
# 1     4610000  300 M2         5-10  3  Mülk Sahibi Oturuyor     04 Ocak 2023
# 2     1200000  120 M2     0 (Yeni)  4                   Boş     04 Ocak 2023
# 3      800000  160 M2        16-20  6       Kiracı Oturuyor   28 Aralık 2022
# 4     1850000  155 M2            2  7  Mülk Sahibi Oturuyor  28 Haziran 2022
# ...       ...     ...          ... ..                   ...              ...
# 1302  2100000  188 M2     0 (Yeni)  6                   Boş   14 Aralık 2022
# 1303  1550000  125 M2        11-15  3       Kiracı Oturuyor   14 Aralık 2022
# 1304  2995000  145 M2         5-10  2  Mülk Sahibi Oturuyor   14 Aralık 2022
# 1305   550000   90 M2  21 Ve Üzeri  5       Kiracı Oturuyor   14 Aralık 2022
# 1306  2490000  165 M2         5-10  4  Mülk Sahibi Oturuyor   14 Aralık 2022
#
# ...
