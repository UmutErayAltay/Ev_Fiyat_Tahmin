# %%
from selenium import webdriver
import time
import pandas as pd
import numpy as np

# %%
browser = webdriver.Chrome()
def listToString(s):  
    # initialize an empty string 
    str1 = " " 
    # return string   
    return (str1.join(s)) 
browser.get("https://www.emlakjet.com/satilik-konut/bursa/")
k = 49
while (k<=50):
    if(k!=1):
        browser.get("https://www.emlakjet.com/satilik-konut/bursa/"+str(k))
        
    browser.minimize_window()
    k+=1
    time.sleep(1)
    i=9
    while (i<=10):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]
 

            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 12
    while (i<=13):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 1
    while (i<=2):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    
    i=4
    while (i<=7):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 650);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        time.sleep(3)
        tikla.click()
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 15
    while (i<=17):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 18
    while (i<=24):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 26
    while (i<=31):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)


            df_yeni = df.iloc[6:26]


            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
    i = 33
    while (i<=34):
        detaylar = []
        fiyat = []
        browser.execute_script("window.scrollTo(0, 350);")
        tikla = browser.find_element("xpath",'//*[@id="listing-search-wrapper"]/div['+str(i)+']')
        i += 1
        tikla.click()
        time.sleep(1)
        elements = browser.find_elements("css selector", '._3tH_Nw')
        fiyatlar = browser.find_elements("css selector", '._2TxNQv')
        browser.execute_script("window.scrollTo(0, 350);")
        for j in elements:
            detaylar.append(j.text)
        for j in fiyatlar:
            fiyat.append(j.text)
        fiyat_sade = fiyat[1].strip()
        fiyat_sade = fiyat_sade.replace("TL","")
        fiyat_sade = fiyat_sade.replace(".","")
        fiyat_sade = fiyat_sade.replace(",","")
        for j in range(100, 0, -1):
            if fiyat_sade.find("arrow_downward%"+j.__str__())!=-1 or fiyat_sade.find("arrow_upward%"+j.__str__())!=-1:
                fiyat_sade = fiyat_sade.replace("arrow_downward%"+j.__str__(),"")
                fiyat_sade = fiyat_sade.replace("arrow_upward%"+j.__str__(),"")
        fiyat_sade = int(fiyat_sade)
        print(fiyat_sade)
        if (fiyat_sade<10000000):           
            içerikler = []
            içerikler.append([fiyat_sade])
            det_str = listToString(detaylar)
            ayrı = det_str.split("\n")

            df = pd.DataFrame(ayrı)

            df_yeni = df.iloc[6:26]

            df_yeni = df_yeni.reset_index()
            df_yeni.drop("index", axis=1, inplace=True)
            df_liste = df_yeni.values.tolist()
            a = 1
            while a <= len(df_yeni):
                içerikler.append(df_liste[a])
                a= a+2
            df_içerikler = pd.DataFrame(içerikler).T
            df_içerikler.to_csv(r"zingat3.csv", encoding="utf-8", index=False, mode="a")            
            browser.execute_script("window.history.go(-1)")
        else:
            browser.execute_script("window.history.go(-1)")
browser.quit()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [2], in <cell line: 7>()
#       5     # return string
#       6     return (str1.join(s))
# ----> 7 browser.get("https://www.emlakjet.com/satilik-konut/bursa/")
#       8 k = 49
#       9 while (k<=50):
#
# File ~\anaconda4\lib\site-packages\selenium\webdriver\remote\webdriver.py:442, in WebDriver.get(self, url)
#     438 def get(self, url: str) -> None:
#     439     """
#     440     Loads a web page in the current browser session.
#     441     """
# --> 442     self.execute(Command.GET, {'url': url})
#
# File ~\anaconda4\lib\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File ~\anaconda4\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: received Inspector.detached event
#   (failed to check if window was closed: disconnected: Unable to receive message from renderer)
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x008FF243]
# 	(No symbol) [0x00887FD1]
# 	(No symbol) [0x0077D04D]
# 	(No symbol) [0x00770A79]
# 	(No symbol) [0x007706F1]
# 	(No symbol) [0x0076FB0B]
# 	(No symbol) [0x0076FA5C]
# 	(No symbol) [0x0076F356]
# 	(No symbol) [0x007830DD]
# 	(No symbol) [0x007DCDCE]
# 	(No symbol) [0x007C8386]
# 	(No symbol) [0x007A163C]
# 	(No symbol) [0x007A269D]
# 	GetHandleVerifier [0x00B99A22+2655074]
# 	GetHandleVerifier [0x00B8CA24+2601828]
# 	GetHandleVerifier [0x009A8C0A+619850]
# 	GetHandleVerifier [0x009A7830+614768]
# 	(No symbol) [0x008905FC]
# 	(No symbol) [0x00895968]
# 	(No symbol) [0x00895A55]
# 	(No symbol) [0x008A051B]
# 	BaseThreadInitThunk [0x74E77D69+25]
# 	RtlInitializeExceptionChain [0x76F8BB9B+107]
# 	RtlClearBits [0x76F8BB1F+191]

# %%
df_zingat = pd.read_csv("zingat3.csv")
df_zingat
# Out:
#             0       1            2  3                     4               5  \
# 0     2150000  110 M2         5-10  5       Kiracı Oturuyor    04 Ocak 2023
# 1           0       1            2  3                     4               5
# 2     4610000  300 M2         5-10  3  Mülk Sahibi Oturuyor    04 Ocak 2023
# 3           0       1            2  3                     4               5
# 4     1200000  120 M2     0 (Yeni)  4                   Boş    04 Ocak 2023
# ...       ...     ...          ... ..                   ...             ...
# 2608  2995000  145 M2         5-10  2  Mülk Sahibi Oturuyor  14 Aralık 2022
# 2609        0       1            2  3                     4               5
# 2610   550000   90 M2  21 Ve Üzeri  5       Kiracı Oturuyor  14 Aralık 2022
# 2611        0       1            2  3                     4               5
# 2612  2490000  165 M2         5-10  4  Mülk Sahibi Oturuyor  14 Aralık 2022
#
#           6       7    8             9              10
# 0     Konut  100 M2  2+1         3.Kat  Kombi Doğalgaz
# 1         6       7    8             9              10
# 2     Konut  250 M2  5+1  Bahçe Dublex  Kombi Doğalgaz
# 3         6       7    8             9              10
# 4     Konut  110 M2  3+1  Yüksek Giriş  Kombi Doğalgaz
# ...     ...     ...  ...           ...             ...
# 2608  Konut  130 M2  3+1         1.Kat  Kombi Doğalgaz
# 2609      6       7    8             9              10
# 2610  Konut   75 M2  2+1         5.Kat  Kombi Doğalgaz
# 2611      6       7    8             9              10
# 2612  Konut  135 M2  3+1  Çatı Dubleks  Kombi Doğalgaz
#
# [2613 rows x 11 columns]

# %%
i = 1
while i <= 2612:
    df_zingat.drop(i,inplace = True)
    i=i+2

# %%
df_zingat = df_zingat.reset_index()
df_zingat.drop("index", axis = 1, inplace = True)
df_zingat.to_csv("zingat4.csv")

# %%
df_zingat
# Out:
#             0       1            2  3                     4                5  \
# 0     2150000  110 M2         5-10  5       Kiracı Oturuyor     04 Ocak 2023
# 1     4610000  300 M2         5-10  3  Mülk Sahibi Oturuyor     04 Ocak 2023
# 2     1200000  120 M2     0 (Yeni)  4                   Boş     04 Ocak 2023
# 3      800000  160 M2        16-20  6       Kiracı Oturuyor   28 Aralık 2022
# 4     1850000  155 M2            2  7  Mülk Sahibi Oturuyor  28 Haziran 2022
# ...       ...     ...          ... ..                   ...              ...
# 1302  2100000  188 M2     0 (Yeni)  6                   Boş   14 Aralık 2022
# 1303  1550000  125 M2        11-15  3       Kiracı Oturuyor   14 Aralık 2022
# 1304  2995000  145 M2         5-10  2  Mülk Sahibi Oturuyor   14 Aralık 2022
# 1305   550000   90 M2  21 Ve Üzeri  5       Kiracı Oturuyor   14 Aralık 2022
# 1306  2490000  165 M2         5-10  4  Mülk Sahibi Oturuyor   14 Aralık 2022
#
#           6       7    8             9                10
# 0     Konut  100 M2  2+1         3.Kat    Kombi Doğalgaz
# 1     Konut  250 M2  5+1  Bahçe Dublex    Kombi Doğalgaz
# 2     Konut  110 M2  3+1  Yüksek Giriş    Kombi Doğalgaz
# 3     Konut  125 M2  2+1         6.Kat    Kombi Doğalgaz
# 4     Konut  145 M2  3+1         3.Kat  Merkezi Doğalgaz
# ...     ...     ...  ...           ...               ...
# 1302  Konut  130 M2  3+1         3.Kat     Yerden Isıtma
# 1303  Konut  115 M2  3+1         1.Kat    Kombi Doğalgaz
# 1304  Konut  130 M2  3+1         1.Kat    Kombi Doğalgaz
# 1305  Konut   75 M2  2+1         5.Kat    Kombi Doğalgaz
# 1306  Konut  135 M2  3+1  Çatı Dubleks    Kombi Doğalgaz
#
# [1307 rows x 11 columns]
